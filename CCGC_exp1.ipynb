# %% [markdown]
# <a href="https://colab.research.google.com/github/sway-am/CCGC_MLRC/blob/main/CCGC_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
import os
from tqdm import tqdm
import warnings
import seaborn as sns
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CCGC_MLRC
# Out:
# /content/drive/MyDrive/CCGC_MLRC

# %%
# !pip install munkres
# !pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### cora

# %%
# !python train.py
# Out:
# Alpha: 0.5
# Threshold: 0.5
# 100% 400/400 [00:14<00:00, 27.28it/s]
# 100% 400/400 [00:13<00:00, 29.31it/s]
# 100% 400/400 [00:13<00:00, 29.43it/s]
# 100% 400/400 [00:13<00:00, 29.63it/s]
# 100% 400/400 [00:13<00:00, 29.82it/s]
# 100% 400/400 [00:13<00:00, 29.07it/s]
# 100% 400/400 [00:13<00:00, 29.25it/s]
# 100% 400/400 [00:13<00:00, 28.95it/s]
# 100% 400/400 [00:14<00:00, 28.39it/s]
# 100% 400/400 [00:13<00:00, 29.29it/s]
# 73.19793205317578 ± 0.5965382719736698
# 56.41022004008546 ± 0.9427888582308374
# 51.95522456508299 ± 0.9195875583527084
# 70.81062854355407 ± 1.075980093519646

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # %run -i train.py --threshold $t
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ...
# 100%|██████████| 400/400 [00:14<00:00, 27.82it/s]
# 73.19793205317578 ± 0.5965382719736698
# 56.41022004008546 ± 0.9427888582308374
# 51.95522456508299 ± 0.9195875583527084
# 70.81062854355407 ± 1.075980093519646
# Alpha: 0.5
# Threshold: 0.6
# ...
# 100%|██████████| 400/400 [00:15<00:00, 26.00it/s]
# 73.85155096011817 ± 0.5056388029685653
# 57.06795671299957 ± 0.834702020576918
# 52.266720852644276 ± 1.1940461728698137
# 71.13757221506391 ± 1.1033315954790779
# Alpha: 0.5
# Threshold: 0.7
# ...
# 100%|██████████| 400/400 [00:17<00:00, 22.53it/s]
# 73.64844903988183 ± 0.5699787705044258
# 57.011662405190314 ± 0.5052952131904738
# 52.263923724663336 ± 1.1600261638196974
# 71.15957505039063 ± 1.3283889445798613

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # %run -i train.py --alpha $a
# Out:
# Alpha: 0.01
# Threshold: 0.7
# ...
# 100%|██████████| 400/400 [00:17<00:00, 23.36it/s]
# 73.64844903988183 ± 0.5699787705044258
# 57.011662405190314 ± 0.5052952131904738
# 52.263923724663336 ± 1.1600261638196974
# 71.15957505039063 ± 1.3283889445798613
# Alpha: 0.1
# Threshold: 0.7
# ...
# 100%|██████████| 400/400 [00:16<00:00, 24.14it/s]
# 73.64844903988183 ± 0.5699787705044258
# 57.011662405190314 ± 0.5052952131904738
# 52.263923724663336 ± 1.1600261638196974
# 71.15957505039063 ± 1.3283889445798613
# Alpha: 1.0
# Threshold: 0.7
# ...
# 100%|██████████| 400/400 [00:17<00:00, 23.36it/s]
# 73.64844903988183 ± 0.5699787705044258
# 57.011662405190314 ± 0.5052952131904738
# 52.263923724663336 ± 1.1600261638196974
# 71.15957505039063 ± 1.3283889445798613
# Alpha: 10.0
# Threshold: 0.7
# ...
# 100%|██████████| 400/400 [00:17<00:00, 23.40it/s]
# 73.64844903988183 ± 0.5699787705044258
# 57.011662405190314 ± 0.5052952131904738
# 52.263923724663336 ± 1.1600261638196974
# 71.15957505039063 ± 1.3283889445798613

# %% [markdown]
# ### BAT

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'bat' --cluster_num $4
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    bat
# feature shape:   (131, 81)
# label shape:     (131,)
# adj shape:       (131, 131)
# undirected edge num:    1038
# category num:           4
# category distribution:
# label 0:32
# label 1:32
# label 2:32
# label 3:35
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:03<00:00, 116.81it/s]
# 100% 400/400 [00:03<00:00, 105.18it/s]
# 100% 400/400 [00:03<00:00, 132.17it/s]
# 100% 400/400 [00:03<00:00, 132.27it/s]
# 100% 400/400 [00:02<00:00, 136.20it/s]
# 100% 400/400 [00:03<00:00, 104.92it/s]
# 100% 400/400 [00:02<00:00, 134.97it/s]
# 100% 400/400 [00:03<00:00, 133.19it/s]
# 100% 400/400 [00:03<00:00, 131.42it/s]
# 100% 400/400 [00:03<00:00, 103.82it/s]
# 76.48854961832062 ± 0.8902216633351574
# 52.3324136388571 ± 1.2043260568692522
# 50.183810529817706 ± 1.4271882734166812
# 76.01913162441997 ± 1.0217688050184799
# Alpha: 0.5
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --alpha $a
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    bat
# feature shape:   (131, 81)
# label shape:     (131,)
# adj shape:       (131, 131)
# undirected edge num:    1038
# category num:           4
# category distribution:
# label 0:32
# label 1:32
# label 2:32
# label 3:35
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:03<00:00, 115.44it/s]
# 100% 400/400 [00:03<00:00, 112.78it/s]
# 100% 400/400 [00:03<00:00, 114.43it/s]
# 100% 400/400 [00:03<00:00, 127.71it/s]
# 100% 400/400 [00:03<00:00, 126.80it/s]
# 100% 400/400 [00:03<00:00, 103.99it/s]
# 100% 400/400 [00:03<00:00, 118.49it/s]
# 100% 400/400 [00:03<00:00, 127.39it/s]
# 100% 400/400 [00:03<00:00, 127.37it/s]
# 100% 400/400 [00:03<00:00, 103.54it/s]
# 76.48854961832062 ± 0.8902216633351574
# 52.3324136388571 ± 1.2043260568692522
# 50.183810529817706 ± 1.4271882734166812
# 76.01913162441997 ± 1.0217688050184799
# Alpha: 0.1
# ...

# %% [markdown]
# ### UAT

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    uat
# feature shape:   (1190, 239)
# label shape:     (1190,)
# adj shape:       (1190, 1190)
# undirected edge num:    13599
# category num:           4
# category distribution:
# label 0:297
# label 1:297
# label 2:297
# label 3:299
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:07<00:00, 54.14it/s]
# 100% 400/400 [00:06<00:00, 65.53it/s]
# 100% 400/400 [00:07<00:00, 54.90it/s]
# 100% 400/400 [00:07<00:00, 55.90it/s]
# 100% 400/400 [00:07<00:00, 50.79it/s]
# 100% 400/400 [00:06<00:00, 62.15it/s]
# 100% 400/400 [00:06<00:00, 60.02it/s]
# 100% 400/400 [00:06<00:00, 60.97it/s]
# 100% 400/400 [00:06<00:00, 57.75it/s]
# 100% 400/400 [00:01<00:00, 249.54it/s]
# 55.226890756302524 ± 2.766939916269805
# 26.621186921749477 ± 2.6665622126439263
# 24.12524298441532 ± 5.447689592695123
# 54.2324857445798 ± 3.369331381791807
# Alpha: 0.5
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --threshold $0.5 --dataset $'uat' --cluster_num $4 --alpha $a
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    uat
# feature shape:   (1190, 239)
# label shape:     (1190,)
# adj shape:       (1190, 1190)
# undirected edge num:    13599
# category num:           4
# category distribution:
# label 0:297
# label 1:297
# label 2:297
# label 3:299
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:06<00:00, 62.12it/s]
# 100% 400/400 [00:06<00:00, 59.16it/s]
# 100% 400/400 [00:06<00:00, 65.85it/s]
# 100% 400/400 [00:06<00:00, 59.34it/s]
# 100% 400/400 [00:06<00:00, 65.96it/s]
# 100% 400/400 [00:06<00:00, 57.53it/s]
# 100% 400/400 [00:06<00:00, 66.46it/s]
# 100% 400/400 [00:06<00:00, 58.55it/s]
# 100% 400/400 [00:06<00:00, 66.09it/s]
# 100% 400/400 [00:01<00:00, 208.77it/s]
# 55.226890756302524 ± 2.766939916269805
# 26.621186921749477 ± 2.6665622126439263
# 24.12524298441532 ± 5.447689592695123
# 54.2324857445798 ± 3.369331381791807
# Alpha: 0.1
# ...

# %% [markdown]
# ###CITEEER

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'citeseer' --cluster_num $6
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    citeseer
# feature shape:   (3327, 3703)
# label shape:     (3327,)
# adj shape:       (3327, 3327)
# undirected edge num:    4614
# category num:           6
# category distribution:
# label 0:264
# label 1:590
# label 2:668
# label 3:701
# label 4:596
# label 5:508
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:17<00:00, 23.09it/s]
# 100% 400/400 [00:17<00:00, 23.32it/s]
# 100% 400/400 [00:17<00:00, 23.04it/s]
# 100% 400/400 [00:17<00:00, 23.38it/s]
# 100% 400/400 [00:16<00:00, 23.72it/s]
# 100% 400/400 [00:17<00:00, 23.32it/s]
# 100% 400/400 [00:16<00:00, 23.54it/s]
# 100% 400/400 [00:17<00:00, 23.36it/s]
# 100% 400/400 [00:16<00:00, 23.82it/s]
# 100% 400/400 [00:16<00:00, 23.53it/s]
# 68.51818455064623 ± 1.2382069535633442
# 42.47191119455779 ± 1.1704785542309482
# 43.32567802033306 ± 1.4323102582563558
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --threshold $0.5 --dataset $'citeseer' --cluster_num $6 --alpha $a
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    citeseer
# feature shape:   (3327, 3703)
# label shape:     (3327,)
# adj shape:       (3327, 3327)
# undirected edge num:    4614
# category num:           6
# category distribution:
# label 0:264
# label 1:590
# label 2:668
# label 3:701
# label 4:596
# label 5:508
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:17<00:00, 23.33it/s]
# 100% 400/400 [00:17<00:00, 22.70it/s]
# 100% 400/400 [00:17<00:00, 23.44it/s]
# 100% 400/400 [00:17<00:00, 22.67it/s]
# 100% 400/400 [00:17<00:00, 23.29it/s]
# 100% 400/400 [00:16<00:00, 23.54it/s]
# 100% 400/400 [00:17<00:00, 22.64it/s]
# 100% 400/400 [00:18<00:00, 21.32it/s]
# 100% 400/400 [00:16<00:00, 23.78it/s]
# 100% 400/400 [00:17<00:00, 22.34it/s]
# 68.51818455064623 ± 1.2382069535633442
# 42.47191119455779 ± 1.1704785542309482
# 43.32567802033306 ± 1.4323102582563558
# ...

# %% [markdown]
# ###EAT

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'eat' --cluster_num $4
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    eat
# feature shape:   (399, 203)
# label shape:     (399,)
# adj shape:       (399, 399)
# undirected edge num:    5994
# category num:           4
# category distribution:
# label 0:99
# label 1:99
# label 2:99
# label 3:102
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:04<00:00, 97.87it/s]
# 100% 400/400 [00:03<00:00, 107.47it/s]
# 100% 400/400 [00:04<00:00, 83.23it/s]
# 100% 400/400 [00:04<00:00, 89.60it/s]
# 100% 400/400 [00:03<00:00, 108.44it/s]
# 100% 400/400 [00:04<00:00, 90.03it/s]
# 100% 400/400 [00:03<00:00, 110.29it/s]
# 100% 400/400 [00:03<00:00, 107.51it/s]
# 100% 400/400 [00:04<00:00, 91.38it/s]
# 100% 400/400 [00:03<00:00, 103.80it/s]
# 55.71428571428571 ± 0.8163657882156589
# 32.2143178734503 ± 0.8578382003457207
# 25.688661053230458 ± 0.8812206973613096
# 55.718095755623075 ± 1.4190681227428161
# Alpha: 0.5
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --threshold $0.5 --dataset $'eat' --cluster_num $4 --alpha $a
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    eat
# feature shape:   (399, 203)
# label shape:     (399,)
# adj shape:       (399, 399)
# undirected edge num:    5994
# category num:           4
# category distribution:
# label 0:99
# label 1:99
# label 2:99
# label 3:102
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:04<00:00, 94.98it/s]
# 100% 400/400 [00:03<00:00, 104.40it/s]
# 100% 400/400 [00:04<00:00, 85.86it/s]
# 100% 400/400 [00:03<00:00, 103.87it/s]
# 100% 400/400 [00:03<00:00, 102.63it/s]
# 100% 400/400 [00:04<00:00, 85.98it/s]
# 100% 400/400 [00:04<00:00, 97.94it/s]
# 100% 400/400 [00:03<00:00, 102.18it/s]
# 100% 400/400 [00:04<00:00, 88.29it/s]
# 100% 400/400 [00:04<00:00, 95.77it/s]
# 55.71428571428571 ± 0.8163657882156589
# 32.2143178734503 ± 0.8578382003457207
# 25.688661053230458 ± 0.8812206973613096
# 55.718095755623075 ± 1.4190681227428161
# Alpha: 0.1
# ...

# %% [markdown]
# AMAP

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'amap' --cluster_num $8
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    amap
# feature shape:   (7650, 745)
# label shape:     (7650,)
# adj shape:       (7650, 7650)
# undirected edge num:    119081
# category num:           8
# category distribution:
# label 0:369
# label 1:1686
# label 2:703
# label 3:915
# label 4:882
# label 5:823
# label 6:1941
# label 7:331
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:31<00:00, 12.72it/s]
# 100% 400/400 [00:31<00:00, 12.87it/s]
# 100% 400/400 [00:31<00:00, 12.67it/s]
# 100% 400/400 [00:31<00:00, 12.73it/s]
# 100% 400/400 [00:31<00:00, 12.75it/s]
# 100% 400/400 [00:31<00:00, 12.72it/s]
# 100% 400/400 [00:34<00:00, 11.65it/s]
# 100% 400/400 [00:31<00:00, 12.64it/s]
# 100% 400/400 [00:31<00:00, 12.55it/s]
# 100% 400/400 [00:32<00:00, 12.49it/s]
# 76.62614379084968 ± 0.27602755027270015
# 65.92459151797809 ± 1.089152799902882
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --threshold $0.5 --dataset $'amap' --cluster_num $8 --alpha $a
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    amap
# feature shape:   (7650, 745)
# label shape:     (7650,)
# adj shape:       (7650, 7650)
# undirected edge num:    119081
# category num:           8
# category distribution:
# label 0:369
# label 1:1686
# label 2:703
# label 3:915
# label 4:882
# label 5:823
# label 6:1941
# label 7:331
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:31<00:00, 12.68it/s]
# 100% 400/400 [00:31<00:00, 12.61it/s]
# 100% 400/400 [00:31<00:00, 12.59it/s]
# 100% 400/400 [00:32<00:00, 12.27it/s]
# 100% 400/400 [00:31<00:00, 12.76it/s]
# 100% 400/400 [00:31<00:00, 12.59it/s]
# 100% 400/400 [00:31<00:00, 12.68it/s]
# 100% 400/400 [00:31<00:00, 12.54it/s]
# 100% 400/400 [00:31<00:00, 12.57it/s]
# 100% 400/400 [00:31<00:00, 12.55it/s]
# 76.62614379084968 ± 0.27602755027270015
# 65.92459151797809 ± 1.089152799902882
# ...
